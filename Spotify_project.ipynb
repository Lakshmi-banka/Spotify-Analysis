# %%
pip install spotipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.5/238.5 KB 7.6 MB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
#adding keys
client_credentials_manager=SpotifyClientCredentials(client_id="de192977b41841fd87b116b7af4851af",client_secret="c55eba2cdb3d48b3993c71f593d5257d")
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)
playlist_link="https://open.spotify.com/playlist/37i9dQZF1E34UIs3oqthBM?si=a384790e9b904e0a"
playlist_URI=playlist_link.split("/")[-1].split('?')[0]
data=sp.playlist_tracks(playlist_URI)
data['items']
# Out:
# [{'added_at': '1970-01-01T00:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rL4uL3xfYOt2p7NHhS8qr'},
#       'href': 'https://api.spotify.com/v1/artists/0rL4uL3xfYOt2p7NHhS8qr',
#       'id': '0rL4uL3xfYOt2p7NHhS8qr',
#       'name': 'Vishal Chandrashekhar',
#       'type': 'artist',
#       'uri': 'spotify:artist:0rL4uL3xfYOt2p7NHhS8qr'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '5d0eh1FoU7tOYEnHLohjjv'

# %%
data['items'][8]['track']['album']['name']
# Out:
# 'Sita Ramam (Telugu) (Extended Version) [Original Motion Picture Soundtrack]'

# %%
data['items'][-1]['track']['album']['release_date']
# Out:
# '2008-07-05'

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/5d0eh1FoU7tOYEnHLohjjv'

# %%
album_list=[]
for row in data['items']:
  album_id=row['track']['album']['id']
  album_name=row['track']['album']['name']
  album_release_date=row['track']['album']['release_date']
  album_total_tracks=row['track']['album']['total_tracks']
  album_url=row['track']['album']['external_urls']['spotify']
  album_element={'album_id':album_id,'name':album_name,'release_date':album_release_date,'total_tracks':album_total_tracks,'url':album_url}
  album_list.append(album_element)

# %%
print(album_list)
# Out:
# [{'album_id': '5d0eh1FoU7tOYEnHLohjjv', 'name': 'Sita Ramam (Telugu) (Extended Version) [Original Motion Picture Soundtrack]', 'release_date': '2022-09-08', 'total_tracks': 10, 'url': 'https://open.spotify.com/album/5d0eh1FoU7tOYEnHLohjjv'}, {'album_id': '0JB0Brs2tTPzy9Su8TKLGl', 'name': 'Boss Party (From "Waltair Veerayya")', 'release_date': '2022-11-23', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/0JB0Brs2tTPzy9Su8TKLGl'}, {'album_id': '0o80h7hMTz2wjzJSvckOcr', 'name': 'Srivalli (From "Pushpa The Rise Part - 01")', 'release_date': '2021-12-14', 'total_tracks': 1, 'url': 'https://open.spotify.com/album/0o80h7hMTz2wjzJSvckOcr'}, {'album_id': '0Qz9VVoDjqs1KwD6mgOFti', 'name': 'Dhamaka (Original Motion Picture Soundtrack)', 'release_date': '2023-01-07', 'total_tracks': 6, 'url': 'https://open.spotify.com/album/0Qz9VVoDjqs1KwD6mgOFti'}, {'album_id': '5I3dEH9cXdYmo8MVIdOkxO', 'name': 'Nuvvostanante Nenoddantana', 'release_date': '2005-01-14', 'total_tracks': 7, 'url': 'http
# ...

# %%
album_list
# Out:
# [{'album_id': '5d0eh1FoU7tOYEnHLohjjv',
#   'name': 'Sita Ramam (Telugu) (Extended Version) [Original Motion Picture Soundtrack]',
#   'release_date': '2022-09-08',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/5d0eh1FoU7tOYEnHLohjjv'},
#  {'album_id': '0JB0Brs2tTPzy9Su8TKLGl',
#   'name': 'Boss Party (From "Waltair Veerayya")',
#   'release_date': '2022-11-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0JB0Brs2tTPzy9Su8TKLGl'},
#  {'album_id': '0o80h7hMTz2wjzJSvckOcr',
#   'name': 'Srivalli (From "Pushpa The Rise Part - 01")',
#   'release_date': '2021-12-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0o80h7hMTz2wjzJSvckOcr'},
#  {'album_id': '0Qz9VVoDjqs1KwD6mgOFti',
#   'name': 'Dhamaka (Original Motion Picture Soundtrack)',
#   'release_date': '2023-01-07',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/0Qz9VVoDjqs1KwD6mgOFti'},
#  {'album_id': '5I3dEH9cXdYmo8MVIdOkxO',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '1970-01-01T00:00:00Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0rL4uL3xfYOt2p7NHhS8qr'},
#      'href': 'https://api.spotify.com/v1/artists/0rL4uL3xfYOt2p7NHhS8qr',
#      'id': '0rL4uL3xfYOt2p7NHhS8qr',
#      'name': 'Vishal Chandrashekhar',
#      'type': 'artist',
#      'uri': 'spotify:artist:0rL4uL3xfYOt2p7NHhS8qr'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
# ...

# %%
artist_list=[]
for row in data['items']:
  for key,value in row.items():
    if key=="track":
      for artist in value['artists']:
        artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],'external_url':artist['href']}
        artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '0rL4uL3xfYOt2p7NHhS8qr',
#   'artist_name': 'Vishal Chandrashekhar',
#   'external_url': 'https://api.spotify.com/v1/artists/0rL4uL3xfYOt2p7NHhS8qr'},
#  {'artist_id': '74S8YRi4XQ5yf9ToSzuY80',
#   'artist_name': 'Sunitha',
#   'external_url': 'https://api.spotify.com/v1/artists/74S8YRi4XQ5yf9ToSzuY80'},
#  {'artist_id': '5sSzCxHtgL82pYDvx2QyEU',
#   'artist_name': 'Devi Sri Prasad',
#   'external_url': 'https://api.spotify.com/v1/artists/5sSzCxHtgL82pYDvx2QyEU'},
#  {'artist_id': '4kq8z3vydHjPDggxb16ErB',
#   'artist_name': 'Nakash Aziz',
#   'external_url': 'https://api.spotify.com/v1/artists/4kq8z3vydHjPDggxb16ErB'},
#  {'artist_id': '1CUAEnzS0hidDnH66AUS3h',
#   'artist_name': 'Haripriya',
#   'external_url': 'https://api.spotify.com/v1/artists/1CUAEnzS0hidDnH66AUS3h'},
#  {'artist_id': '4W91bbPB2CTSsHwt7eqNl7',
#   'artist_name': 'Javed Ali',
#   'external_url': 'https://api.spotify.com/v1/artists/4W91bbPB2CTSsHwt7eqNl7'},
# ...

# %%
song_list=[]
for row in data['items']:
  song_id=row['track']['id']
  song_name=row['track']['name']
  song_duration=row['track']['duration_ms']
  song_url=row['track']['external_urls']['spotify']
  song_popularity=row['track']['popularity']
  song_added=row['added_at']
  album_id=row['track']['album']['id']
  artist_id=row['track']['album']['artists'][0]['id']
  song_element={'song_id':song_id,'song_name':song_name,'song_duration':song_duration,'url':song_url,'popularity':song_popularity,'song_added':song_added,'album_id':album_id,'artist_id':artist_id}
  song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '2UZOnPQRaE4kDVvuitb473',
#   'song_name': 'Ninnati Theepi',
#   'song_duration': 165374,
#   'url': 'https://open.spotify.com/track/2UZOnPQRaE4kDVvuitb473',
#   'popularity': 48,
#   'song_added': '1970-01-01T00:00:00Z',
#   'album_id': '5d0eh1FoU7tOYEnHLohjjv',
#   'artist_id': '0rL4uL3xfYOt2p7NHhS8qr'},
#  {'song_id': '4sJ9X27MSCue4d0t48MXwe',
#   'song_name': 'Boss Party',
#   'song_duration': 200208,
#   'url': 'https://open.spotify.com/track/4sJ9X27MSCue4d0t48MXwe',
#   'popularity': 68,
#   'song_added': '1970-01-01T00:00:00Z',
#   'album_id': '0JB0Brs2tTPzy9Su8TKLGl',
#   'artist_id': '5sSzCxHtgL82pYDvx2QyEU'},
#  {'song_id': '7sVEoPc5ZUUQerRkgTypUZ',
#   'song_name': 'Srivalli (From "Pushpa The Rise Part - 01")',
#   'song_duration': 224072,
#   'url': 'https://open.spotify.com/track/7sVEoPc5ZUUQerRkgTypUZ',
#   'popularity': 69,
#   'song_added': '1970-01-01T00:00:00Z',
#   'album_id': '0o80h7hMTz2wjzJSvckOcr',
#   'artist_id': '4W91bbPB2CTSsHwt7eqNl7'},
# ...

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df.head(50)
# Out:
#                   album_id                                               name  \
# 0   5d0eh1FoU7tOYEnHLohjjv  Sita Ramam (Telugu) (Extended Version) [Origin...
# 1   0JB0Brs2tTPzy9Su8TKLGl               Boss Party (From "Waltair Veerayya")
# 2   0o80h7hMTz2wjzJSvckOcr        Srivalli (From "Pushpa The Rise Part - 01")
# 3   0Qz9VVoDjqs1KwD6mgOFti       Dhamaka (Original Motion Picture Soundtrack)
# 4   5I3dEH9cXdYmo8MVIdOkxO                         Nuvvostanante Nenoddantana
# 5   0YcZWXz8znvFBKuccxHzXh               Krishna Trance (From "Karthikeya 2")
# 6   3Bq1oXhTLEWvDV03ZmrVue  Almost Padipoyindhe Pilla (From "Das Ka Dhamki...
# 7   7w8tu9PbmjDrBP8wAe2JRK                                Ramayya Vasthavayya
# 8   5d0eh1FoU7tOYEnHLohjjv  Sita Ramam (Telugu) (Extended Version) [Origin...
# 9   5QnrY0J2XNF0HtiMVihQOd                            Expression Queen Trisha
# 10  4x0uXmq0RuGBdpXx9bjs8N                 Jinthaak Chithaka (From "Dhamaka")
# ...

# %%
print(album_df)
# Out:
#                   album_id                                               name  \
# 0   5d0eh1FoU7tOYEnHLohjjv  Sita Ramam (Telugu) (Extended Version) [Origin...
# 1   0JB0Brs2tTPzy9Su8TKLGl               Boss Party (From "Waltair Veerayya")
# 2   0o80h7hMTz2wjzJSvckOcr        Srivalli (From "Pushpa The Rise Part - 01")
# 3   0Qz9VVoDjqs1KwD6mgOFti       Dhamaka (Original Motion Picture Soundtrack)
# 4   5I3dEH9cXdYmo8MVIdOkxO                         Nuvvostanante Nenoddantana
# 5   0YcZWXz8znvFBKuccxHzXh               Krishna Trance (From "Karthikeya 2")
# 6   3Bq1oXhTLEWvDV03ZmrVue  Almost Padipoyindhe Pilla (From "Das Ka Dhamki...
# 7   7w8tu9PbmjDrBP8wAe2JRK                                Ramayya Vasthavayya
# 8   5d0eh1FoU7tOYEnHLohjjv  Sita Ramam (Telugu) (Extended Version) [Origin...
# 9   5QnrY0J2XNF0HtiMVihQOd                            Expression Queen Trisha
# 10  4x0uXmq0RuGBdpXx9bjs8N                 Jinthaak Chithaka (From "Dhamaka")
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB
